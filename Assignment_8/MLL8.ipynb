# %%
# !pip install pyod
# !pip install combo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
df = pd.read_csv('creditcardfraud_normalised.csv')

# %%
df
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0       0.935192  0.766490  0.881365  0.313023  0.763439  0.267669  0.266815
# 1       0.978542  0.770067  0.840298  0.271796  0.766120  0.262192  0.264875
# 2       0.935217  0.753118  0.868141  0.268766  0.762329  0.281122  0.270177
# 3       0.941878  0.765304  0.868484  0.213661  0.765647  0.275559  0.266803
# 4       0.938617  0.776520  0.864251  0.269796  0.762975  0.263984  0.268968
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.756448  0.873531  0.666991  0.160317  0.729603  0.236810  0.235393
# 284803  0.945845  0.766677  0.872678  0.219189  0.771561  0.273661  0.265504
# 284804  0.990905  0.764080  0.781102  0.227202  0.783425  0.293496  0.263547
# 284805  0.954209  0.772856  0.849587  0.282508  0.763172  0.269291  0.261175
# 284806  0.949232  0.765256  0.849601  0.229488  0.765632  0.256488  0.274963
#
# ...

# %%
df.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  284807.000000  284807.000000  284807.000000  284807.000000
# mean        0.958294       0.767258       0.837414       0.251930
# std         0.033276       0.017424       0.026275       0.062764
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.942658       0.760943       0.821985       0.214311
# 50%         0.958601       0.767949       0.840530       0.251050
# 75%         0.980645       0.775739       0.855214       0.284882
# max         1.000000       1.000000       1.000000       1.000000
#
#                   V5             V6             V7             V8  \
# count  284807.000000  284807.000000  284807.000000  284807.000000
# mean        0.765716       0.263020       0.265356       0.785385
# std         0.009292       0.013395       0.007537       0.012812
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      284807 non-null  float64
#  1   V2      284807 non-null  float64
#  2   V3      284807 non-null  float64
#  3   V4      284807 non-null  float64
#  4   V5      284807 non-null  float64
#  5   V6      284807 non-null  float64
#  6   V7      284807 non-null  float64
#  7   V8      284807 non-null  float64
#  8   V9      284807 non-null  float64
#  9   V10     284807 non-null  float64
#  10  V11     284807 non-null  float64
#  11  V12     284807 non-null  float64
#  12  V13     284807 non-null  float64
#  13  V14     284807 non-null  float64
#  14  V15     284807 non-null  float64
#  15  V16     284807 non-null  float64
#  16  V17     284807 non-null  float64
#  17  V18     284807 non-null  float64
#  18  V19     284807 non-null  float64
#  19  V20     284807 non-null  float64
# ...

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# class     0
# dtype: int64

# %%
# Boxplot
sns.boxplot(x='class', y='Amount', data=df)
plt.title('Boxplot of Amount by Class')
plt.show()

# Histogram
sns.histplot(df['Amount'], bins=50)
plt.title('Histogram of Amount')
plt.show()

# Heatmap
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.title('Heatmap of Correlations')
plt.show()

# %%
# prompt: Apply at 3 outlier detection algorithm from pyOD and take ensemble.

from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.lof import LOF
from pyod.models.combination import aom, moa, average, maximization

# Define the outlier detection algorithms
abod = ABOD()
iforest = IForest()
lof = LOF()

# Apply the algorithms to the data
abod_scores = abod.fit_predict(df)
iforest_scores = iforest.fit_predict(df)
lof_scores = lof.fit_predict(df)

# Ensemble the results
ensemble_scores = maximization(abod_scores, iforest_scores, lof_scores)

# Identify outliers
outliers = df[ensemble_scores == 1]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function fit_predict is deprecated
#   warnings.warn(msg, category=FutureWarning)

# %%
import pandas as pd

actual_anomalies = df[df['class'] == 1]

comparison = pd.merge(outliers, actual_anomalies, how='inner', indicator=True)

print(comparison)
